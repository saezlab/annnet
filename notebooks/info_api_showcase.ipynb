# %% [markdown]
# # annnet environment snapshot
#
# A compact notebook showing package metadata and only the backends and I/O capabilities that are currently available in the active environment.

# %%
# !source source .venv/bin/activate
# !uv pip install --python .venv/bin/python -e ..
# Out:
# /bin/bash: line 1: source: No such file or directory
# Resolved 4 packages in 21ms
# Prepared 1 package in 521ms
# Uninstalled 1 package in 1ms
# Installed 1 package in 3ms file:///home/daniele/annnet)
#  ~ annnet==0.1.0 (from file:///home/daniele/annnet)

# %%
import annnet as an

an.info()
# Out:
# Installed version: v0.1.0
# License: BSD-3-Clause
# Authors: Youssef Zerta <youssef.zerta@biomedtech.ueuromed.org>, Daniele Bottazzi <daniele.bottazzi@mail.polimi.it>, Denes Turei <turei.denes@gmail.com>
# Available graph backends: networkx: no (annnet[networkx]); igraph: no (annnet[igraph]); graph-tool: no (pixi / conda-forge / system package); pyg: no (annnet[pyg])
# Available plot backends: matplotlib: no (annnet[plot] or [matplotlib]); graphviz: no (annnet[plot]); pydot: no (annnet[plot])
# Available tabular backends: polars: no (annnet[polars]); pandas: no (annnet[pandas]); pyarrow: no (annnet[parquet])
# Available I/O modules: annnet: yes; json/ndjson: yes; dataframes: yes; csv: yes; excel: no (annnet[excel]); graphml/gexf: no (annnet[networkx]); sif: yes; cx2: yes; parquet: no (annnet[parquet]); zarr: no (annnet[zarr_io]); sbml: no (annnet[sbml]); omnipath: yes
# Repository: https://github.com/saezlab/annnet
# Documentation: https://saezlab.github.io/annnet/reference/
# ...

# %% [markdown]
# If you install or remove optional dependencies and rerun the notebook, the tables update automatically because `an.info()` inspects the current environment at call time.

# %%
# !uv pip install -e "..[networkx]"
an.info()
# Out:
# Resolved 5 packages in 42ms
# Prepared 1 package in 427ms
# Installed 5 packages in 162ms
#  + annnet==0.1.0 (from file:///home/daniele/annnet)
#  + narwhals==2.18.1
#  + networkx==3.6.1
#  + numpy==2.4.3
#  + scipy==1.17.1
# Installed version: v0.1.0
# License: BSD-3-Clause
# Authors: Youssef Zerta <youssef.zerta@biomedtech.ueuromed.org>, Daniele Bottazzi <daniele.bottazzi@mail.polimi.it>, Denes Turei <turei.denes@gmail.com>
# Available graph backends: networkx: yes; igraph: no (annnet[igraph]); graph-tool: no (pixi / conda-forge / system package); pyg: no (annnet[pyg])
# Available plot backends: matplotlib: no (annnet[plot] or [matplotlib]); graphviz: no (annnet[plot]); pydot: no (annnet[plot])
# Available tabular backends: polars: no (annnet[polars]); pandas: no (annnet[pandas]); pyarrow: no (annnet[parquet])
# ...

# %%
# !uv pip install -e "..[plot, io]"
an.info()
# Out:
# Resolved 28 packages in 203ms
# Prepared 1 package in 470ms
# Uninstalled 1 package in 0.99ms
# Installed 25 packages in 310ms
#  ~ annnet==0.1.0 (from file:///home/daniele/annnet)
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + donfig==0.8.1.post1
#  + et-xmlfile==2.0.0
#  + fonttools==4.62.1
#  + google-crc32c==1.8.0
#  + graphviz==0.21
#  + kiwisolver==1.5.0
#  + lxml==6.0.2
#  + matplotlib==3.10.8
#  + numcodecs==0.16.5
#  + openpyxl==3.1.5
#  + packaging==26.0
#  + pandas==3.0.1
#  + pillow==12.1.1
#  + pyarrow==23.0.1
#  + pydot==4.0.1
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + pyyaml==6.0.3
#  + six==1.17.0
#  + toml==0.10.2
#  + typing-extensions==4.15.0
#  + zarr==3.1.6
# Installed version: v0.1.0
# License: BSD-3-Clause
# Authors: Youssef Zerta <youssef.zerta@biomedtech.ueuromed.org>, Daniele Bottazzi <daniele.bottazzi@mail.polimi.it>, Denes Turei <turei.denes@gmail.com>
# ...
